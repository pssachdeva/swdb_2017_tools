# %%
#Import Modules
import os
import deconvolution_tools.deconvolution_tools as dt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
drive_path = '/Volumes/Brain2017/data/dynamic-brain-workshop/brain_observatory_cache/'

from allensdk.core.brain_observatory_cache import BrainObservatoryCache
manifest_file = os.path.join(drive_path,'brain_observatory_manifest.json')
boc = BrainObservatoryCache(manifest_file=manifest_file)

# %%
ophys_experiment_id = 546341286 #example experiment

dataset = boc.get_ophys_experiment_data(ophys_experiment_id)

# %%
spikes, timestamps_dict, spike_times, isis = dt.get_epoch_spiking_data(boc, ophys_experiment_id, num_std=6)

# %%
spike_times.keys()
# Out:
# [u'natural_movie_two',
#  u'locally_sparse_noise_4deg',
#  u'spontaneous',
#  u'natural_movie_one',
#  u'locally_sparse_noise_8deg']

# %%
i = 0
for k, spike_time in spike_times['spontaneous'].iteritems():
    plt.scatter(spike_time, np.ones(len(spike_time)) + i, s=0.2, c='k', marker='o')
    i+=1
